# %%
# 1. Unzip your project
# !unzip PCB_DETECTION.zip -d /content/
# Out:
# Archive:  PCB_DETECTION.zip
#    creating: /content/PCB DETECTION/.firebase/
#   inflating: /content/PCB DETECTION/.firebase/hosting.ZnJvbnRlbmQ.cache
#   inflating: /content/PCB DETECTION/.firebaserc
#   inflating: /content/PCB DETECTION/.gitignore
#    creating: /content/PCB DETECTION/backend/
#   inflating: /content/PCB DETECTION/backend/.dockerignore
#   inflating: /content/PCB DETECTION/backend/.env.example
#   inflating: /content/PCB DETECTION/backend/.env.production
#    creating: /content/PCB DETECTION/backend/.git/
#  extracting: /content/PCB DETECTION/backend/.git/COMMIT_EDITMSG
#   inflating: /content/PCB DETECTION/backend/.git/config
#   inflating: /content/PCB DETECTION/backend/.git/description
#  extracting: /content/PCB DETECTION/backend/.git/HEAD
#    creating: /content/PCB DETECTION/backend/.git/hooks/
#   inflating: /content/PCB DETECTION/backend/.git/hooks/applypatch-msg.sample
#   inflating: /content/PCB DETECTION/backend/.git/hooks/commit-msg.sample
# ...

# %%
# 2. Install the required libraries
# !pip install pyngrok flask werkzeug tensorflow opencv-python-headless

# %%
# !pip install ultralytics reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.0 MB/s eta 0:00:00
# ...

# %%
import os
# Move into your project folder
os.chdir('/content/PCB DETECTION/backend')
print(f"Current Directory: {os.getcwd()}")
# Out:
# Current Directory: /content/PCB DETECTION/backend

# %%
# 3. Set up ngrok to create a public URL
from pyngrok import ngrok

# Kill any existing ngrok tunnels just in case
ngrok.kill()

# Set your auth token (Keep the quotes around your token)
ngrok.set_auth_token("3C1yc8BSAz0DS8PDPIErZa4tSw6_7pTHiZREtPMy8tdxhZLFH")

# Open a tunnel on port 5000 (Flask's default port)
public_url = ngrok.connect(5000)
print("================================================================")
print(f"🌍 YOUR APP IS LIVE ON THE INTERNET AT: {public_url}")
print("================================================================")

# 4. Start the Flask server
# !python app.py
# Out:
# ...
# 🌍 YOUR APP IS LIVE ON THE INTERNET AT: NgrokTunnel: "https://pretenceful-nondegrading-dorothy.ngrok-free.dev" -> "http://localhost:5000"
# ...
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/Apr/2026 14:47:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2026 14:47:40] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [07/Apr/2026 14:47:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2026 14:48:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2026 14:48:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2026 14:48:45] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2026 14:48:46] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [07/Apr/2026 14:52:22] "POST /detect HTTP/1.1" 200 -
# ...

# %%
# !pkill ngrok
